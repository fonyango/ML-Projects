# %% [markdown]
# #### 1.0 Setting up the environment

# %%
#set up
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import texthero as hero
from PIL import Image

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import datetime
import nltk
from nltk.stem.porter import *
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# #### 2.0 Loading the Datasets

# %%
#reads the datasets
aljazeera = pd.read_csv('n_aljazeera.csv')
bbc = pd.read_csv('n_bbc.csv')
bloomberg = pd.read_csv('n_bloomberg.csv')
conversation_dw = pd.read_csv('n_conversation-dw.csv')
citizen = pd.read_csv('n_citizen.csv')
cgtn_cnbc = pd.read_csv('n_ctgn-cnbc.csv')
east_african = pd.read_csv('n_east_african.csv')
france24 = pd.read_csv('n_france.csv')
guardian = pd.read_csv('n_guardian.csv')
k24 = pd.read_csv('n_k24.csv')
nation = pd.read_csv('n_nation.csv')
nytimes_independent = pd.read_csv('n_nytimes-independent.csv')
people_daily = pd.read_csv('n_pd.csv')
star = pd.read_csv('n_star.csv')
standard = pd.read_csv('n_standard.csv')
observer = pd.read_csv('n_observer.csv')
tribune = pd.read_csv('n_tribune.csv')
independent_uganda = pd.read_csv('n_independent-uganda.csv')
kbc = pd.read_csv('n_kbc.csv')
new_vision = pd.read_csv('n_new_vision.csv')
monitor = pd.read_csv('new_monitor.csv')
capital = pd.read_csv('n_capital-news.csv')

# %% [markdown]
# #### 2.1 Preliminary Checks

# %%
#Combining the datasets
data = pd.concat([aljazeera, bbc,bloomberg,conversation_dw,cgtn_cnbc, citizen,east_african,france24,guardian,k24,
                 nation,nytimes_independent,people_daily,star,standard, observer, tribune, monitor,
                  independent_uganda,new_vision,kbc,capital])
data.shape
# Out:
# (621, 8)

# %%
#check the first 5 rows of the dataframe
data.head()
# Out:
#                                                 link news_country  \
# 0  https://www.aljazeera.com/videos/2020/04/10/ke...        Qatar
# 1  https://www.aljazeera.com/news/2020/1/25/east-...        Qatar
# 2  https://www.aljazeera.com/news/2020/4/13/locus...        Qatar
# 3  https://www.aljazeera.com/gallery/2020/1/20/in...        Qatar
# 4  https://www.aljazeera.com/gallery/2020/2/18/in...        Qatar
#
#   newspaper_name                                               text  \
# 0      aljazeera  Kenya locust threat: Fears second wave will be...
# 1      aljazeera  Billions of locusts swarming through East Afri...
# 2      aljazeera  The UN says locusts in Ethiopia have damaged 2...
# 3      aljazeera  A serious outbreak of locusts is spreading in ...
# 4      aljazeera  Uganda has scrambled to respond to the arrival...
#
#                                                title        date  \
# 0  Kenya locust threat: Fears second wave will be...  10/04/2020
# 1  East Africa locust outbreak sparks calls for i...  25/01/2020
# 2  Locust invasion creates food crisis for 1 mill...  13/04/2020
# 3  In Pictures: Locust outbreak spreads across Ea...  20/01/2020
# 4  In Pictures: Desert locusts swarm parts of Eas...  18/02/2020
#
#                                             keywords  \
# 0  ['threat', 'resources', 'kenya', 'wave', 'harv...
# 1  ['africa', 'outbreak', 'region', 'kenya', 'dro...
# 2  ['creates', 'ethiopia', 'sudan', 'region', 'li...
# 3  ['africa', 'reported', 'outbreak', 'sudan', 'p...
# 4  ['africa', 'york', 'million', 'outbreak', 'ken...
#
#                                              summary
# 0  Kenya locust threat: Fears second wave will be...
# 1  Billions of locusts swarming through East Afri...
# 2  The UN says locusts in Ethiopia have damaged 2...
# 3  A serious outbreak of locusts is spreading in ...
# 4  Uganda has scrambled to respond to the arrival...

# %%
#change name of newspaper_name column
data = data.rename(columns={'newspaper_name':'news_website'})
data.columns
# Out:
# Index(['link', 'news_country', 'news_website', 'text', 'title', 'date',
#        'keywords', 'summary'],
#       dtype='object')

# %%
#Check the data types of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          621 non-null    object
#  1   news_country  621 non-null    object
#  2   news_website  621 non-null    object
#  3   text          621 non-null    object
#  4   title         621 non-null    object
#  5   date          565 non-null    object
#  6   keywords      577 non-null    object
#  7   summary       577 non-null    object
# dtypes: object(8)
# memory usage: 43.7+ KB

# %%
#Check missing values
data.isnull().sum()
# Out:
# link             0
# news_country     0
# news_website     0
# text             0
# title            0
# date            56
# keywords        44
# summary         44
# dtype: int64

# %% [markdown]
# #### 3.0 Preprocessing

# %% [markdown]
# ##### 3.1 Cleaning the Text Column

# %%
#using texthero for preprocessing
data['clean_text'] = hero.clean(data['text'])
data.head()
# Out:
#                                                 link news_country  \
# 0  https://www.aljazeera.com/videos/2020/04/10/ke...        Qatar
# 1  https://www.aljazeera.com/news/2020/1/25/east-...        Qatar
# 2  https://www.aljazeera.com/news/2020/4/13/locus...        Qatar
# 3  https://www.aljazeera.com/gallery/2020/1/20/in...        Qatar
# 4  https://www.aljazeera.com/gallery/2020/2/18/in...        Qatar
#
#   news_website                                               text  \
# 0    aljazeera  Kenya locust threat: Fears second wave will be...
# 1    aljazeera  Billions of locusts swarming through East Afri...
# 2    aljazeera  The UN says locusts in Ethiopia have damaged 2...
# 3    aljazeera  A serious outbreak of locusts is spreading in ...
# 4    aljazeera  Uganda has scrambled to respond to the arrival...
#
#                                                title        date  \
# 0  Kenya locust threat: Fears second wave will be...  10/04/2020
# 1  East Africa locust outbreak sparks calls for i...  25/01/2020
# 2  Locust invasion creates food crisis for 1 mill...  13/04/2020
# 3  In Pictures: Locust outbreak spreads across Ea...  20/01/2020
# 4  In Pictures: Desert locusts swarm parts of Eas...  18/02/2020
#
#                                             keywords  \
# 0  ['threat', 'resources', 'kenya', 'wave', 'harv...
# 1  ['africa', 'outbreak', 'region', 'kenya', 'dro...
# 2  ['creates', 'ethiopia', 'sudan', 'region', 'li...
# 3  ['africa', 'reported', 'outbreak', 'sudan', 'p...
# 4  ['africa', 'york', 'million', 'outbreak', 'ken...
#
#                                              summary  \
# 0  Kenya locust threat: Fears second wave will be...
# 1  Billions of locusts swarming through East Afri...
# 2  The UN says locusts in Ethiopia have damaged 2...
# 3  A serious outbreak of locusts is spreading in ...
# 4  Uganda has scrambled to respond to the arrival...
#
#                                           clean_text
# 0  kenya locust threat fears second wave worse ha...
# 1  billions locusts swarming east africa could pr...
# 2  un says locusts ethiopia damaged hectares crop...
# 3  serious outbreak locusts spreading parts east ...
# 4  uganda scrambled respond arrival biggest locus...

# %%
data.shape
# Out:
# (621, 9)

# %% [markdown]
# ##### 3.2 Cleaning Title Column

# %%
#using texthero for preprocessing
data['clean_title'] = hero.clean(data['title'])
data.head()
# Out:
#                                                 link news_country  \
# 0  https://www.aljazeera.com/videos/2020/04/10/ke...        Qatar
# 1  https://www.aljazeera.com/news/2020/1/25/east-...        Qatar
# 2  https://www.aljazeera.com/news/2020/4/13/locus...        Qatar
# 3  https://www.aljazeera.com/gallery/2020/1/20/in...        Qatar
# 4  https://www.aljazeera.com/gallery/2020/2/18/in...        Qatar
#
#   news_website                                               text  \
# 0    aljazeera  Kenya locust threat: Fears second wave will be...
# 1    aljazeera  Billions of locusts swarming through East Afri...
# 2    aljazeera  The UN says locusts in Ethiopia have damaged 2...
# 3    aljazeera  A serious outbreak of locusts is spreading in ...
# 4    aljazeera  Uganda has scrambled to respond to the arrival...
#
#                                                title        date  \
# 0  Kenya locust threat: Fears second wave will be...  10/04/2020
# 1  East Africa locust outbreak sparks calls for i...  25/01/2020
# 2  Locust invasion creates food crisis for 1 mill...  13/04/2020
# 3  In Pictures: Locust outbreak spreads across Ea...  20/01/2020
# 4  In Pictures: Desert locusts swarm parts of Eas...  18/02/2020
#
#                                             keywords  \
# 0  ['threat', 'resources', 'kenya', 'wave', 'harv...
# 1  ['africa', 'outbreak', 'region', 'kenya', 'dro...
# 2  ['creates', 'ethiopia', 'sudan', 'region', 'li...
# 3  ['africa', 'reported', 'outbreak', 'sudan', 'p...
# 4  ['africa', 'york', 'million', 'outbreak', 'ken...
#
#                                              summary  \
# 0  Kenya locust threat: Fears second wave will be...
# 1  Billions of locusts swarming through East Afri...
# 2  The UN says locusts in Ethiopia have damaged 2...
# 3  A serious outbreak of locusts is spreading in ...
# 4  Uganda has scrambled to respond to the arrival...
#
#                                           clean_text  \
# 0  kenya locust threat fears second wave worse ha...
# 1  billions locusts swarming east africa could pr...
# 2  un says locusts ethiopia damaged hectares crop...
# 3  serious outbreak locusts spreading parts east ...
# 4  uganda scrambled respond arrival biggest locus...
#
#                                          clean_title
# 0  kenya locust threat fears second wave worse ha...
# 1  east africa locust outbreak sparks calls inter...
# 2  locust invasion creates food crisis million et...
# 3  pictures locust outbreak spreads across east a...
# 4    pictures desert locusts swarm parts east africa

# %% [markdown]
# ##### 3.3 Formating Date column

# %%
data['date'].unique()
# Out:
# array(['10/04/2020', '25/01/2020', '13/04/2020', '20/01/2020',
#        '18/02/2020', '03/04/2020', '09/04/2020', '19/02/2020',
#        '21/01/2020', '19/04/2020', '10/02/2020', nan, '22/03/2020',
#        '10/09/2020', '05/08/2020', '21/05/2020', '08/04/2020',
#        '2020-01-29 09:10:17+00:00', '2020-02-25 07:15:43+00:00',
#        '2020-02-26 09:40:32+00:00', '2020-02-17 13:43:19+00:00',
#        '2020-02-05 14:35:50+00:00', '2020-02-21 04:31:01+00:00',
#        '2020-09-03 13:26:02+00:00', '2020-01-05 15:14:30+00:00',
#        '2020-03-10 09:29:35+00:00', '2020-01-10 11:34:44+00:00',
#        '2020-02-19 05:30:00+00:00', '2020-02-15 11:44:50+00:00'],
#       dtype=object)

# %%
# convert the 'Date' column to datetime format
data['date']= pd.to_datetime(data['date'],utc=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          621 non-null    object
#  1   news_country  621 non-null    object
#  2   news_website  621 non-null    object
#  3   text          621 non-null    object
#  4   title         621 non-null    object
#  5   date          565 non-null    datetime64[ns, UTC]
#  6   keywords      577 non-null    object
#  7   summary       577 non-null    object
#  8   clean_text    621 non-null    object
#  9   clean_title   621 non-null    object
# dtypes: datetime64[ns, UTC](1), object(9)
# memory usage: 53.4+ KB

# %%
data['new_date'] = pd.to_datetime(data['date'].dt.strftime('%Y-%m-%d'))

# %%
data.head(2)
# Out:
#                                                 link news_country  \
# 0  https://www.aljazeera.com/videos/2020/04/10/ke...        Qatar
# 1  https://www.aljazeera.com/news/2020/1/25/east-...        Qatar
#
#   news_website                                               text  \
# 0    aljazeera  Kenya locust threat: Fears second wave will be...
# 1    aljazeera  Billions of locusts swarming through East Afri...
#
#                                                title  \
# 0  Kenya locust threat: Fears second wave will be...
# 1  East Africa locust outbreak sparks calls for i...
#
#                        date  \
# 0 2020-10-04 00:00:00+00:00
# 1 2020-01-25 00:00:00+00:00
#
#                                             keywords  \
# 0  ['threat', 'resources', 'kenya', 'wave', 'harv...
# 1  ['africa', 'outbreak', 'region', 'kenya', 'dro...
#
#                                              summary  \
# 0  Kenya locust threat: Fears second wave will be...
# 1  Billions of locusts swarming through East Afri...
#
#                                           clean_text  \
# 0  kenya locust threat fears second wave worse ha...
# 1  billions locusts swarming east africa could pr...
#
#                                          clean_title   new_date
# 0  kenya locust threat fears second wave worse ha... 2020-10-04
# 1  east africa locust outbreak sparks calls inter... 2020-01-25

# %%
data['DayOfWeek'] = data['new_date'].dt.day_name()

# %%
data['month_published'] = data['new_date'].dt.month_name()

# %%
data['year_published'] = data['new_date'].dt.year

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 621 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   link             621 non-null    object
#  1   news_country     621 non-null    object
#  2   news_website     621 non-null    object
#  3   text             621 non-null    object
#  4   title            621 non-null    object
#  5   date             565 non-null    datetime64[ns, UTC]
#  6   keywords         577 non-null    object
#  7   summary          577 non-null    object
#  8   clean_text       621 non-null    object
#  9   clean_title      621 non-null    object
#  10  new_date         565 non-null    datetime64[ns]
#  11  DayOfWeek        565 non-null    object
#  12  month_published  565 non-null    object
#  13  year_published   565 non-null    float64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), object(11)
# memory usage: 72.8+ KB

# %%
#Saves the csv file of the clean_data
data.to_csv('clean_data.csv', index=False)
